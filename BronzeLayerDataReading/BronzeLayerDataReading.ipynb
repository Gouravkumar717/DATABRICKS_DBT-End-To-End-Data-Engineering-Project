# %%
# %sql
-- Selecting all columns from the airports data Delta table in the specified volume path
SELECT * FROM delta.`/Volumes/workspace/bronze/bronzevolume/airports/data/`

# %%
# %sql
-- Selecting all columns from the bookings data Delta table in the specified volume path
SELECT * FROM delta.`/Volumes/workspace/bronze/bronzevolume/bookings/data/`

# %%
# %sql
-- Selecting all columns from the flights data Delta table in the specified volume path
SELECT * FROM delta.`/Volumes/workspace/bronze/bronzevolume/flights/data/`

# %%
# %sql
-- Selecting all columns from the passengers data Delta table in the specified volume path
SELECT * FROM delta.`/Volumes/workspace/bronze/bronzevolume/passengers/data/`
