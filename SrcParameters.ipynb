# %%
# Define a list of dictionaries, each containing a 'src' key representing different data sources
src_array = [
    {"src":"bookings"},
    {"src":"airports"},
    {"src":"flights"},
    {"src":"passengers"}
]

# %%
# Store the src_array list in the Databricks job task values under the key "output_key".
dbutils.jobs.taskValues.set(key = "output_key", value = src_array)
